# %%
print("Welcome to Python World")
# Out:
# Welcome to Python World

# %% [markdown]
# Python Keywords

# %%
import keyword
print(keyword.kwlist)
print(len(keyword.kwlist))
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']
# 35

# %% [markdown]
# Python Identifiers(variables)

# %%
var=36
print(var)
1var=36
# Out:
#   File "/tmp/ipykernel_4474/2900870382.py", line 3
#     1var=36
#     ^
# SyntaxError: invalid decimal literal

# %%
@var=36
# Out:
#   File "/tmp/ipykernel_4474/2498496044.py", line 1
#     @var=36
#      ^
# SyntaxError: invalid syntax. Maybe you meant '==' or ':=' instead of '='?

# %%
employee_salary=30000

# %%
import=100
# Out:
#   File "/tmp/ipykernel_4474/3910542285.py", line 1
#     import=100
#           ^
# SyntaxError: invalid syntax

# %% [markdown]
# Comments in python

# %%
#single line comment

"""multiline
comment
here
in python
"""
# Out:
# 'multiline\ncomment\nhere\nin python\n'

# %% [markdown]
# Variable Assignements

# %%
student_age=22 #int variable
print(type(student_age))

#multiple Assignment
var1,var2,var3=100,200,300
print(var1,var2,var3)

var1=var2=var3=100
print(var1,var2,var3)
# Out:
# <class 'int'>
# 100 200 300
# 100 100 100

# %% [markdown]
# **Python Data Types**
#
#
# *   Numerical: int,float,complex,bool
# *   String
#
# Collection Datatypes/Sequences/Data structure: List,Tuple,set, dict
#
# Dynamic Typing

# %%
#Numerical Datatype

int_var=23
print(type(int_var))

float_var=23.5
print(type(float_var))

#Size(bytes) of the variable
import sys
print(sys.getsizeof(int_var))
print(sys.getsizeof(float_var))

#Validate Data type
print(isinstance(int_var,float))
# Out:
# <class 'int'>
# <class 'float'>
# 28
# 24
# False

# %%
#complex
complex_var=2+3j
print(type(complex_var))
# Out:
# <class 'complex'>

# %%
#static typing  int salary=10000;

#Dynamic Typing
var=100
print(type(var))

var=100.5
print(type(var))

var=True
print(type(var))

var=[50,60,70,80]
print(type(var))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'bool'>
# <class 'list'>

# %% [markdown]
# Collection Datatypes/Sequences: String, List, Tuple, Set, Dict
#
# Mutable/Immutable,Ordered/Unordered(index),Allow Duplicates or not
#
# - String: Immutable,ordered, allow duplicates
#
# - List: Mutable, Ordered, Allow Duplicates
#
# - Tuple: Immutable, Ordered, allow duplicates
#
# - Set: Mutable, Unordered, DO NOT allow duplicates
#
# - Dict: Follows Key-value pairs, unordered, keys-immutable, value-mutable, keys-no duplicates, values-allow duplicates

# %% [markdown]
# Python Strings

# %%
name="Rajiv"
name='Kapil'

#multiline string
name='''Rajiv
Kapil'''
print(name)
print(type(name))
# Out:
# Rajiv
# Kapil
# <class 'str'>

# %%
#string index(order)
name='John Dell'
print(len(name))
print(name[0]) #first character of the string
print(name[-1]) #last character of the string)
print(name[6])
print(name[-6])
# Out:
# 9
# J
# l
# e
# n

# %%
#String Slicing
#str[start:stop:step]  start:inclusive Stop:exclusive
#default start:0, stop:end of the string, step:1
var="abcdefghijklmnop"
print(var[0:5])
print(var[:5])
print(var[5:])
print(var[0:10:2])
print(var[::-1]) #reverse string
# Out:
# abcde
# abcde
# fghijklmnop
# acegi
# ponmlkjihgfedcba

# %%
#Immutable string
var[0]='X'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_4474/1166846332.py in <cell line: 0>()
#       1 #Immutable string
# ----> 2 var[0]='X'
#
# TypeError: 'str' object does not support item assignment

# %%
#Iteration String
for char in var:
  print(char)

# %%
for char in enumerate(var):
  print(char)

# %%
#String membership
print("Aj" in "Ajith")
print("Ai" in "Ajith")
print('th' not in "Ajith")
# Out:
# True
# False
# False

# %%
var='ajith1'
Var='ajith2'
print(var)
print(Var)
# Out:
# ajith1
# ajith2

# %% [markdown]
# **Python Lists**

# %%
employee=[1001,'Amit Kumar','sales',45000,4.6]
print(employee)
print(type(employee))
# Out:
# [1001, 'Amit Kumar', 'sales', 45000, 4.6]
# <class 'list'>

# %%
#index
print(employee[0])
#Mutable
employee[3]=55000
print(employee)
#duplicates
lst=[10,10,10,10,20,20,30,40]
print(lst)
# Out:
# 1001
# [1001, 'Amit Kumar', 'sales', 55000, 4.6]
# [10, 10, 10, 10, 20, 20, 30, 40]

# %%
#List of function
#print(dir(employee))

for i in dir(employee):
  print(i)
# Out:
# __add__
# __class__
# __class_getitem__
# __contains__
# __delattr__
# __delitem__
# __dir__
# __doc__
# __eq__
# __format__
# __ge__
# __getattribute__
# __getitem__
# __getstate__
# __gt__
# __hash__
# __iadd__
# __imul__
# __init__
# __init_subclass__
# __iter__
# __le__
# __len__
# __lt__
# __mul__
# __ne__
# __new__
# __reduce__
# __reduce_ex__
# __repr__
# __reversed__
# __rmul__
# __setattr__
# __setitem__
# __sizeof__
# __str__
# __subclasshook__
# append
# clear
# copy
# count
# extend
# index
# insert
# pop
# remove
# reverse
# sort

# %%
print(employee.sort.__doc__)
# Out:
# Sort the list in ascending order and return None.
#
# The sort is in-place (i.e. the list itself is modified) and stable (i.e. the
# order of two equal elements is maintained).
#
# If a key function is given, apply it once to each list item and sort them,
# ascending or descending, according to their function values.
#
# The reverse flag can be set to sort in descending order.

# %% [markdown]
# Add/Remove Items

# %%
print(employee)
# Out:
# [1001, 'Amit Kumar', 'sales', 55000, 4.6]

# %%
#Add item(s): append(item), extend([item1,item2,item3]), insert(index,item)
employee.append('Newyork')
print(employee)
# Out:
# [1001, 'Amit Kumar', 'sales', 55000, 4.6, 'Newyork']

# %%
employee.pop()

# %%
print(employee)

# %%
employee.extend([1000,2000,3000])
print(employee)
# Out:
# [1001, 'Amit Kumar', 'sales', 55000, 4.6, 'Newyork', 1000, 2000, 3000]

# %%
#add new item at perticular index
employee.insert(3,'Astt. Manager')
print(employee)

# %%
employee.insert(0,[10,20,30])
print(employee)

# %%
#Remove item: pop(index),remove(item)
employee.pop()
print(employee)

# %%
print("Popped off item:",employee.pop(0))
print(employee)

# %%
employee.remove(1000)
print(employee)

# %%
lst=[45,63,98,23,75,81,24,45,36,25,23]
lst.remove(45)
print(lst)

# %%
lst=[45,63,98,23,75,81,24,45,36,25,23]

for i in lst:
  if i==45:
    lst.remove(45)

print(lst)

# %%
lst=[45,63,98,23,75,81,24,45,36,25,23]
print(lst.index(45))
print(lst.count(45))

# %%
#Membership
print(employee)

# %%
print("sales" in employee)
print('Manhattan' not in employee)

# %%
#join lists
lst1=[10,20,30]
lst2=[40,50,60]
lst3=lst1+lst2  #concat
print(lst3)

# %%
#join() function
input_str=["Hello", "Good Morning" ,"Everyone"]
welcome_str=" ".join(input_str)
print(welcome_str)

# %% [markdown]
# List Comprehensions: Single line operation to create new lists from existing lists, it can include expression and conditions

# %%
lst=[23,36,98,56,23,75,48,12,56,39,53,23,21]
even_lst=[i for i in lst if i%2==0]  #List comprehensions
print(even_lst)
# Out:
# [36, 98, 56, 48, 12, 56]

# %%
new_lst=[i for i in lst if i%3==0 if i%9==0 if i%12==0]
print(new_lst)
# Out:
# [36]

# %%
sample_str="one 1 two 2 three 3 four 4 five 5"
numbers=[int(x) for x in sample_str if x.isdigit()]
alpha=[x for x in sample_str if x.isalpha()]
print(numbers)
print(alpha)
# Out:
# [1, 2, 3, 4, 5]
# ['o', 'n', 'e', 't', 'w', 'o', 't', 'h', 'r', 'e', 'e', 'f', 'o', 'u', 'r', 'f', 'i', 'v', 'e']

# %%
lst=['XS','S','M','L','XL']
new_lst=['Extra Small' if i=='XS' else ('Small' if i=='S' else ('Medium' if i=='M' else('Large' if i=='L' else 'Extra Large'))) for i in lst]
print(new_lst)
# Out:
# ['Extra Small', 'Small', 'Medium', 'Large', 'Extra Large']

# %% [markdown]
# **Python Tuple** : Immutable

# %%
tup=(1001, 'Amit Kumar', 'sales', 55000, 4.6, 'Newyork')
print(tup)
print(type(tup))
print(tup[0])
# Out:
# (1001, 'Amit Kumar', 'sales', 55000, 4.6, 'Newyork')
# <class 'tuple'>
# 1001

# %%
#Immutable
tup[3]=60000
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_13772/337437543.py in <cell line: 0>()
#       1 #Immutable
# ----> 2 tup[3]=60000
#
# TypeError: 'tuple' object does not support item assignment

# %%
for i in dir(tup):
  print(i)
# Out:
# __add__
# __class__
# __class_getitem__
# __contains__
# __delattr__
# __dir__
# __doc__
# __eq__
# __format__
# __ge__
# __getattribute__
# __getitem__
# __getnewargs__
# __getstate__
# __gt__
# __hash__
# __init__
# __init_subclass__
# __iter__
# __le__
# __len__
# __lt__
# __mul__
# __ne__
# __new__
# __reduce__
# __reduce_ex__
# __repr__
# __rmul__
# __setattr__
# __sizeof__
# __str__
# __subclasshook__
# count
# index

# %% [markdown]
# Can we have Mutable Tuple ?

# %%
tup=([10,20],[30,40])
print(type(tup))
tup[0][0]=100
print(tup)
# Out:
# <class 'tuple'>
# ([100, 20], [30, 40])

# %% [markdown]
# **Python Set**
#
# Unordered(no index), NO duplicates allowed

# %%
sample_set={45,63,92,'one',4.3,45,63,'one'}
print(type(sample_set))
print(sample_set)
# Out:
# <class 'set'>
# {4.3, 'one', 92, 45, 63}

# %%
#No index
print(sample_set[0])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_13772/2013316842.py in <cell line: 0>()
#       1 #No index
# ----> 2 print(sample_set[0])
#
# TypeError: 'set' object is not subscriptable

# %% [markdown]
# Adding/Remove item from set

# %%
print(sample_set)
# Out:
# {4.3, 'one', 92, 45, 63}

# %%
#Add items to set
sample_set.add(99)
print(sample_set)
sample_set.add(45)
print(sample_set)

sample_set.update([100,200,99,45,63])
print(sample_set)
# Out:
# {99, 4.3, 'one', 92, 45, 63}
# {99, 4.3, 'one', 92, 45, 63}
# {99, 4.3, 100, 200, 'one', 92, 45, 63}

# %%
#Remove item: remove(), discard()
sample_set.remove(45) #remove item in a set

# %%
print(sample_set)
# Out:
# {99, 4.3, 100, 200, 'one', 92, 63}

# %% [markdown]
# **Set Opration**: Union, intersecation, set_difference

# %%
#Union
set_a={10,20,30,40,50}
set_b={30,20,60,50,80}

print(set_a|set_b)
print(set_a.union(set_b))
# Out:
# {40, 10, 80, 50, 20, 60, 30}
# {40, 10, 80, 50, 20, 60, 30}

# %%
#Intersection
print(set_a & set_b)
print(set_a.intersection(set_b))
# Out:
# {50, 20, 30}
# {50, 20, 30}

# %%
#Set_difference
print(set_a-set_b)
print(set_a.difference(set_b))
# Out:
# {40, 10}
# {40, 10}

# %% [markdown]
# Python Dictionary
# - Key-value pair {key:value}

# %%
mydict={'id':1001,'name':'Amit Kumar','dept':'sales','salary':55000, 100:'abc'}
print(mydict)
print(type(mydict))
# Out:
# {'id': 1001, 'name': 'Amit Kumar', 'dept': 'sales', 'salary': 55000, 100: 'abc'}
# <class 'dict'>

# %%
print(mydict['salary'])
mydict['salary']=60000  #Mutable
print(mydict)
# Out:
# 55000
# {'id': 1001, 'name': 'Amit Kumar', 'dept': 'sales', 'salary': 60000, 100: 'abc'}

# %%
print(mydict.keys()) #only keys available
print(mydict.values()) #only values
print(mydict.items()) #tuple of key-value
# Out:
# dict_keys(['id', 'name', 'dept', 'salary', 100])
# dict_values([1001, 'Amit Kumar', 'sales', 60000, 'abc'])
# dict_items([('id', 1001), ('name', 'Amit Kumar'), ('dept', 'sales'), ('salary', 60000), (100, 'abc')])

# %%
#fromkeys()
keys=mydict.keys()
new_dict=dict.fromkeys(keys)
print(new_dict)
# Out:
# {'id': None, 'name': None, 'dept': None, 'salary': None, 100: None}

# %%
new_dict['id']=[1001,1002,1003]
new_dict['name']=['Ajith','Kapil','Parul']
print(new_dict)
# Out:
# {'id': [1001, 1002, 1003], 'name': ['Ajith', 'Kapil', 'Parul'], 'dept': None, 'salary': None, 100: None}

# %%
#Adding/remove key:pair
print(mydict)
mydict["location"]="Newyork"
print(mydict)
mydict['name']='Rajiv Kumar'
print(mydict)
# Out:
# {'id': 1001, 'name': 'Amit Kumar', 'dept': 'sales', 'salary': 60000, 100: 'abc', 'location': 'Newyork'}
# {'id': 1001, 'name': 'Amit Kumar', 'dept': 'sales', 'salary': 60000, 100: 'abc', 'location': 'Newyork'}
# {'id': 1001, 'name': 'Rajiv Kumar', 'dept': 'sales', 'salary': 60000, 100: 'abc', 'location': 'Newyork'}

# %%
#Remove key-value pair
mydict.pop(100)
print(mydict)
# Out:
# {'id': 1001, 'name': 'Rajiv Kumar', 'dept': 'sales', 'salary': 60000, 'location': 'Newyork'}

# %%
#Traverse Dict
for i in mydict:
  print(i,':',mydict[i])
# Out:
# id : 1001
# name : Rajiv Kumar
# dept : sales
# salary : 60000
# location : Newyork

# %%
#Dict to Dataframes(tables)
import pandas as pd

print(new_dict)
new_dict['salary']=[45000,65000,78000]
new_dict['dept']=['sales','HR','R&D']
print(new_dict)

df=pd.DataFrame(new_dict)
print(df)
# Out:
# {'id': [1001, 1002, 1003], 'name': ['Ajith', 'Kapil', 'Parul'], 'dept': None, 'salary': None, 100: None}
# {'id': [1001, 1002, 1003], 'name': ['Ajith', 'Kapil', 'Parul'], 'dept': ['sales', 'HR', 'R&D'], 'salary': [45000, 65000, 78000], 100: None}
#      id   name   dept  salary   100
# 0  1001  Ajith  sales   45000  None
# 1  1002  Kapil     HR   65000  None
# 2  1003  Parul    R&D   78000  None

# %% [markdown]
# **Type casting**

# %%
var1=10
var2=23.14
var3=var1+var2  #Implicit type casting
print(var3)
# Out:
# 33.14

# %%
#Explicit Type casting
#int(),float(),str(),list(),tuple(),set()...
var1=float(var1)
print(var1)

#print(int('abc123'))

lst=[10,20,20,20,30,20,10,30,30,40,50,60]
print(list(set(lst)))
# Out:
# 10.0
# [40, 10, 50, 20, 60, 30]

# %% [markdown]
# **Python Inputs**

# %%
#keyboard input
year=int(input("Enter your birth year:"))#input() gives a string by default
print(year)
print(type(year))
print(f"You are {2026-year} year old !")
# Out:
# Enter your birth year:1989
# 1989
# <class 'int'>
# You are 37 year old !

# %% [markdown]
# **Python Operators **
#
# ![image.png](data:image/png;base64,...)

# %%
#Airthmetic Opr
print(10%3) #Remainder
print(10**3) #raised to the power X^Y
print(100/3)  #float value
print(100//3) #Floor division gives integer value
# Out:
# 1
# 1000
# 33.333333333333336
# 33

# %%
#Assignment Opr
var1=10   #assignment
var1+=100  #var1=var1+100
print(var1)
# Out:
# 110

# %%
var1=var2
print(var1==100)
print(var1!=100)

# %%
#logical-and
year=int(input("Enter your birth year:")) #input() gives a string by default
age=2026-year
if age>=18 and age<=45:
    print("You are eligible for this job")
else:
    print("You are not eligible for this job")
# Out:
# Enter your birth year:1987
# You are eligible for this job

# %%
#logical-or
year=int(input("Enter your birth year:")) #input() gives a string by default
age=2026-year
if age>=18 or age<=45:
    print("You are eligible for this job")
else:
    print("You are not eligible for this job")
# Out:
# Enter your birth year:1990
# You are eligible for this job

# %% [markdown]
# **Python Flow Control**
#
# Conditional Flow: if, if-else, elif
#
# Loops(iteration): for, while

# %% [markdown]
# **Guess the number !**

# %%
import random
number=random.randint(1,100)
attempts=0

while True:
  guess=int(input("Guess a number in between 1 and 100:"))
  attempts+=1

  if guess==number:
    print(f"Congratulations! You guessed the number {number} in {attempts} attempts.")
    print("Game over.")
    break
  elif guess<number:
    print("Too low! Try again.")
  else:
    print("Too high! Try again.")
# Out:
# Guess a number in between 1 and 100:59
# Too low! Try again.
# Guess a number in between 1 and 100:89
# Too high! Try again.
# Guess a number in between 1 and 100:69
# Too low! Try again.
# Guess a number in between 1 and 100:74
# Too low! Try again.
# Guess a number in between 1 and 100:79
# Too high! Try again.
# Guess a number in between 1 and 100:77
# Too low! Try again.
# Guess a number in between 1 and 100:78
# Congratulations! You guessed the number 78 in 7 attempts.
# Game over.

# %%
#Break and Continue-Jump Statements
lst=[45,63,23,8,96,12,14,45,23,63]
for i in lst:
  print(i)
  if i==8:
    print("Number found")
    break

# %%
lst=[45,63,23,8,96,12,14,45,23,63]
for i in lst:
  print(i)
  if i==45:
    print("Number found")
    continue

# %% [markdown]
# ### **Python Functions (Modular programs)**

# %% [markdown]
# - A function is a block of organized code written to carry out a specified task.
#
# - Functions help break our program into smaller and modular chunks for better readability.
#
# - Information can be passed into a function as arguments.
#
# - Parameters are specified after the function name inside the parentheses.
#
# - We can add as many parameters as we want. Parameters must be separated with a comma.
#
# - A function may or may not return data.
#
# - In Python a function is defined using the __def__ keyword
#
# ## Parameter VS Argument
#
#  - A parameter is the variable listed inside the parentheses in the function definition.
#
#  - An argument is the value that is sent to the function when it is called.
#
# ## Three types of functions in Python:-
#
# - __Built-in function :-__  Python predefined functions that are readily available for use like min() , max() , sum() , print() etc.
#
# - __User-Defined Functions:-__ Function that we define ourselves to perform a specific task.
#
# - __Anonymous functions :__ Function that is defined without a name. Anonymous functions are also called as lambda functions. They are not declared with the __def__ keyword

# %%
#Define Function
def details(id,name,country):
  print("ID:",id)
  print("Name:",name)
  print("Country:",country)

# %%
#Call/Invoke Function
details(101,"John","USA")
# Out:
# ID: 101
# Name: John
# Country: USA

# %%
details(102,'Amit',"India")
# Out:
# ID: 102
# Name: Amit
# Country: India

# %%
def square(n):
  sq=n**2
  return sq

# %%
print(square(800))
# Out:
# 640000

# %%
def even_items(lst):
  even=[]
  for i in lst:
    if i%2==0:
      even.append(i)
  return even

print(f"Even items form the list are:{even_items([32,62,98,78,41,75,84,3,78,25])}")
# Out:
# Even items form the list are:[32, 62, 98, 78, 84, 78]

# %% [markdown]
# Types of Arguments

# %%
#1.Required Positional Arguments (default)

def details(id,name,country):
  print("ID:",id)
  print("Name:",name)
  print("country",country)

#details(1001,'Amit') #details() missing 1 required positional argument: 'country'
details('Amit',1001,'USA')
# Out:
# ID: Amit
# Name: 1001
# country USA

# %%
#2. Keyword Argument
#details(id=1001,name="Amit",country="USA")
details(name='John',country='USA',id=1002)
#details(name=123,country='USA',id=1002)
#details(name=123,country='USA')
# Out:
# ID: 1002
# Name: John
# country USA

# %%
#3. Default Arguments
def details_new(id,name,country='USA'):
  print("ID:",id)
  print("Name:",name)
  print("country",country)

details_new(1001,'Amit')
details_new(1001,'Amit','India')
# Out:
# ID: 1001
# Name: Amit
# country USA
# ID: 1001
# Name: Amit
# country India

# %%
#4. Arbitary Arguments: multiple values against single argument
def func(*names):
  print(type(names))
  for name in names:
    print("Hi,",name)

# %%
func("Kapil","Lokesh",'John')
func("Kapil","Lokesh",'John','Parun')

# %%
#Alternate of Arbitary
def func1(names):
  print(type(names))
  for name in names:
    print("Hi,",name)

func1(["Kapil","Lokesh",'John','Parun'])

# %%
#Mix of Arguments
def details_new1(id,name,country='USA'):
  print("ID:",id)
  print("Name:",name)
  print("country",country)

details_new1(id=45,"Kapil",country='USA') #positional argument follows keyword argument

# %%
#5. Key-Arbitary Arguments: useful with Dict as input
def details_new2(**details_emp):
  print(details_emp)

details_new2(**{'id':1001,'name':'John','country':'USA'})

# %%
#Type Hints (NO Enforment)
#def func2(var1: int,var2: str)-> str:

# %%
#Strict typing
def func2(var1 : int,var2 : str):
  if not isinstance(var1, int) or isinstance(var2, str):
    raise TypeError("Arguments must be in defined data types")
  return "Sucess"

# %%
func2(var1="abc",var2=123)
#func2(var1=123,var2="abc")

# %% [markdown]
# **Python Lambda**
#
# Anonymous functions : Function that is defined without a name. Anonymous functions are also called as lambda functions. They are not declared with the def keyword

# %%
# lambda <arguments>:<expression>
#method1
result=(lambda a,b,c:a*b*c)(4,5,6)
print(result)

# %%
#method2
print(result(1,2,6))

# %% [markdown]
# Special Function:
#
# - filter(lambda exp, sequence)
#
# - map(lambda exp, sequence)
#
# - reduce(lambda exp, sequence)

# %%
#Normal Function
def even_items(lst):
  even=[]
  for i in lst:
    if i%2==0:
      even.append(i)
  return even

# %%
even=list(filter(lambda n:n%2==0,[14,65,98,56,23,54,75,12,96,32,58,96]))
print(even)

numbers=list(filter(lambda var:var.isnumeric(),["one","2",'three',"4","five","6"]))
print(numbers)

# %%
result=list(map(lambda x:x**3,[10,20,30,40,50,60]))
print(result)

# %%
#reduce:returns only one value
from functools import reduce
result=reduce(lambda x,y:x+y,[14, 98, 56, 54, 12, 96, 32, 58, 96])
print(result)

# %%
#Finding minimum value in the list
lst=[10,85,32,69,75,36,12,75,85,96,45,12]
min_value=reduce(lambda x,y:x if x<y else y,lst)
max_value=reduce(lambda x,y:x if x>y else y,lst)
print(min_value)
print(max_value)

# %% [markdown]
# **Python Object Oriented Programing**

# %% [markdown]
# - A Class is an object constructor or a "blueprint" for creating objects.
#
# - Objects are nothing but an encapsulation of variables and functions into a single entity.
#
# - Objects get their variables and functions from classes.
#
# - To create a class we use the keyword class.
#
# - The first string inside the class is called docstring which gives the brief description about the class.
#
# - All classes have a function called ____init____() which is always executed when the class is being initiated.
#
# - We can use ____init____() function to assign values to object properties or other operations that are necessary to perform when the object is being created
#
# - The self parameter is a reference to the current instance of the class and is used to access class variables.
#
# - self must be the first parameter of any function in the class
#
# - The super() builtin function returns a temporary object of the superclass that allows us to access methods of the base class.
#
# - super() allows us to avoid using the base class name explicitly and to enable multiple inheritance.

# %%
# Create an employee class
class Employee:
  def __init__(self, name, empid): # __init__() function is used to assign values for name and empid
    self.name = name
    self.empid = empid
    print("Constructor Called.")
  def greet(self): # Class Method
    print(f"Thanks for joining ABC Company {self.name}!!")
    print("Location of self",id(self))

emp1 = Employee("Asif", 34163)  # Create an employee object

print('Name :- ',emp1.name)
print('Employee ID :- ',emp1.empid)
emp1.greet()
print("Location of the object:",id(emp1))

# %%
emp2=Employee("Kapil",1002)
emp2.greet()  #Internal call:emp2.greet(emp2)

# %% [markdown]
# Access Specifiers/Modifiers: User Defined Public, Protected and Private Attributes

# %%
#public   var_name
#private  __var_name
#protected _var_name

class myclass:
    def __init__(self):  # Explanation of __init__ is explained in further examples
        self.__pri="I am Private"
        self._pro="I am Protected"
        self.pub="I am Public"

    def func(self):
        print("you are in func body with in the class")
        print(self.__pri)  #with in the class

ob=myclass()
print(ob.pub)  #outside the class
print(ob._pro)
#print(ob.__pri)  # This line of code will throw error because private attributes can't be accessed outside the class in this way
ob.func()

# %%
class Employee:
    def __init__(self):
        self.__empId=101
        self._empName='Smith'
        self.salary=25000
    def public_method(self):
        print('This is a public method')
        print(self.__empId)
    def _protected_method(self):
        print('This is a protected method')
    def __private_method(self):
        print('This is a private method')
Employee1=Employee()
#print(Employee1.__empId)
Employee1.public_method()

# %% [markdown]
# **Inheritance: Code Reusability**

# %% [markdown]
# - Inheritance is a powerful feature in object oriented programming.
#
# - Inheritance provides code reusability in the program because we can use an existing class (Super Class/ Parent Class / Base Class) to create a new class (Sub Class / Child Class / Derived Class) instead of creating it from scratch.
#
# - The child class inherits data definitions and methods from the parent class which facilitates the reuse of features already available. The child class can add few more definitions or redefine a base class method.
#
# - Inheritance comes into picture when a new class possesses the 'IS A' relationship with an existing class. E.g Student is a person. Hence person is the base class and student is derived class.

# %%
#Single Inheritence (one parent class)
class person:   # Parent Class
    def __init__(self, name , age , gender):
        self.name = name
        self.age = age
        self.gender = gender

    def PersonInfo(self):
        print('Name :- {}'.format(self.name))
        print('Age :- {}'.format(self.age))
        print('Gender :- {}'.format(self.gender))




class student(person): # Child Class
    def __init__(self,name,age,gender,studentid,fees):
        person.__init__(self,name,age,gender)  #Calling the constructor of Parents
        self.studentid = studentid
        self.fees = fees

    def StudentInfo(self):
        print('Student ID :- {}'.format(self.studentid))
        print('Fees :- {}'.format(self.fees))



class teacher(person): # Child Class
    def __init__(self,name,age,gender,empid,salary):
        person.__init__(self,name,age,gender)
        self.empid = empid
        self.salary = salary

    def TeacherInfo(self):
        print('Employee ID :- {}'.format(self.empid))
        print('Salary :- {}'.format(self.salary))



stud1 = student('Asif' , 24 , 'Male' , 123 , 1200)
print('Student Details')
print('---------------')
stud1.PersonInfo()    # PersonInfo() method presnt in Parent Class will be accessible by child class
stud1.StudentInfo()
print()



teacher1 = teacher('Basit' , 36 , 'Male' , 456 , 80000)
print('Employee Details')
print('---------------')
teacher1.PersonInfo()    # PersonInfo() method presnt in Parent Class will be accessible by child class
teacher1.TeacherInfo()

# %%
#2. Multiple Inheritance(many parent classes)
# Super Class
class Father:
    def __init__(self):
        self.fathername = str()


# Super Class
class Mother:
    def __init__(self):
        self.mothername = str()


# Sub Class
class Son(Father, Mother):
    name = str()
    def show(self):
        print('My Name :- ',self.name)
        print("Father :", self.fathername)
        print("Mother :", self.mothername)


s1 = Son()
s1.name = 'Bill'
s1.fathername = "John"
s1.mothername = "Kristen"
s1.show()

# %%
#Problem with Multiple Inheritance
# Super Class
class Father:
    def __init__(self):
        self.fathername = str()

    def func(self):
         print("Some function in Father class")

# Super Class
class Mother:
    def __init__(self):
        self.mothername = str()

    def func(self):
         print("Some function in Mother class")

# Sub Class
class Son(Mother,Father): #MRO: Method resolution order
    name = str()
    def show(self):
        print('My Name :- ',self.name)
        print("Father :", self.fathername)
        print("Mother :", self.mothername)


s1 = Son()
s1.name = 'Bill'
s1.fathername = "John"
s1.mothername = "Kristen"
s1.show()

s1.func()

# %%
#3.Multi-level Inheritance
class person:   # Parent Class
    def __init__(self, name , age , gender):
        self.name = name
        self.age = age
        self.gender = gender

    def PersonInfo(self):
        print('Name :- {}'.format(self.name))
        print('Age :- {}'.format(self.age))
        print('Gender :- {}'.format(self.gender))




class employee(person): # Child Class for Person Class
    def __init__(self,name,age,gender,empid,salary):
        person.__init__(self,name,age,gender)
        self.empid = empid
        self.salary = salary

    def employeeInfo(self):
        print('Employee ID :- {}'.format(self.empid))
        print('Salary :- {}'.format(self.salary))




class fulltime(employee): # Grand Child Class
    def __init__(self,name,age,gender,empid,salary,WorkExperience):
        employee.__init__(self,name,age,gender,empid,salary)
        self.WorkExperience = WorkExperience

    def FulltimeInfo(self):
        print('Work Experience :- {}'.format(self.WorkExperience))




class contractual(employee): # Grand Child Class
    def __init__(self,name,age,gender,empid,salary,ContractExpiry):
        employee.__init__(self,name,age,gender,empid,salary)
        self.ContractExpiry = ContractExpiry

    def ContractInfo(self):
        print('Contract Expiry :- {}'.format(self.ContractExpiry))


print('Contractual Employee Details')
print('****************************')
contract1 = contractual('Basit' , 36 , 'Male' , 456 , 80000,'21-12-2021')
contract1.PersonInfo()
contract1.employeeInfo()
contract1.ContractInfo()

print('\n \n')

print('Fulltime Employee Details')
print('****************************')
fulltim1= fulltime('Asif' , 22 , 'Male' , 567 , 70000, 12)
fulltim1.PersonInfo()
fulltim1.employeeInfo()
fulltim1.FulltimeInfo()

# %% [markdown]
# Polymorphism: Method Overridding
#
# - Overriding is a very important part of object oreinted programming because it makes inheritance exploit its full power.
#
# - Overriding is the ability of a class (Sub Class / Child Class / Derived Class) to change the implementation of a method provided by one of its parent classes.
#
# - When a method in a subclass has the same name, same parameter and same return type as a method in its super-class, then the method in the subclass is said to override the method in the super-class.
#
# - The version of a method that is executed will be determined by the object that is used to invoke it.
#
# - If an object of a parent class is used to invoke the method, then the version in the parent class will be executed, but if an object of the subclass is used to invoke the method, then the version in the child class will be executed.

# %%
class person:   # Parent Class
    def __init__(self, name , age , gender):
        self.name = name
        self.age = age
        self.gender = gender

    def greet(self):
        print("Hello Person")



class student(person): # Child Class
    def __init__(self,name,age,gender,studentid,fees):
        person.__init__(self,name,age,gender)
        self.studentid = studentid
        self.fees = fees

    def greet(self):
        print("Hello Student")  #overridden definition


stud = student('Gabriel' , 56 , 'Male' , 45 , 345678)
stud.greet() # greet() method defined in subclass will be triggered as "stud" is an object of child class

person1 = person('Gabriel' , 56 , 'Male')
person1.greet() # greet() method defined in superclass will be triggered because "person1" is an object of parent class

# %%
# Method Overriding

class Rectangle():
    def __init__(self,length,breadth):
        self.length = length
        self.breadth = breadth
    def getArea(self):
        print(self.length*self.breadth," is area of rectangle")

class Square(Rectangle):
    def __init__(self,s):
        self.side = s
        #Rectangle.__init__(self,side,side)
    def getArea(self):
        print(self.side*self.side," is area of square")

s = Square(4)
#s1=Square(10)
r = Rectangle(2,4)
s.getArea()
r.getArea()

# %% [markdown]
# **Error & Exception Handling**
#
# - Python has many built-in exceptions (ArithmeticError, ZeroDivisionError, EOFError, IndexError, KeyError, SyntaxError, IndentationError, FileNotFoundError etc) that are raised when your program encounters an error.
#
#
# - When the exception occurs Python interpreter stops the current process and passes it to the calling process until it is handled. If exception is not handled the program will crash.
#
#
# - Exceptions in python can be handled using a __try__ statement. The __try__ block lets you test a block of code for errors.
#
#
# - The block of code which can raise an exception is placed inside the try clause. The code that will handle the exceptions is written in the __except__ clause.
#
#
# - The __finally__ code block will execute regardless of the result of the try and except blocks.
#
#
# - We can also use the __else__ keyword to define a block of code to be executed if no exceptions were raised.
#
#
# - Python also allows us to create our own exceptions that can be raised from the program using the __raise__ keyword and caught using the __except__ clause. We can define what kind of error to raise, and the text to print to the user.

# %%
import sys
try:
    var1=int(input("Enter var1:"))
    var2=int(input("Enter var2:"))
    print(var1/var2) # ZeroDivisionError will be encountered here. So the control will pass to except block

except:
    print(sys.exc_info()[1] , 'Exception occured') # This statement will be executed

else:
    print('No exception occurred') # This will be skipped as code block inside try encountered an exception

finally:
    print('Run this block of code always') # This will be always executed

# %%
import os
try:
    os.remove("test3.txt") # FileNotFoundError will be encountered as "test3.txt" is not present in the directory

except:                     # Below statement will be executed as exception occured.
    print("BELOW EXCEPTION OCCURED")
    print(sys.exc_info()[1])

else:
    print('\nNo exception occurred')

finally:
    print('\nRun this block of code always')

# %%
#Multiple Exceptions
# Handling specific exceptions
try:
    x = int(input('Enter first number :- '))
    y =  int(input('Enter first number :- '))  # If input entered is non-zero the control will move to next line
    print(x/y)
    os.remove("test3.txt")

except NameError:
    print('NameError exception occurred')

except FileNotFoundError:
    print('FileNotFoundError exception occurred')

except ZeroDivisionError:
    print('ZeroDivisionError exception occurred')

# %%
#Custom Exception
class NegativeNumberError(Exception):
    pass

def check_number(num):
    if num < 0:
        raise NegativeNumberError("Negative value detected")
    return num

try:
    check_number(-10)
except NegativeNumberError as e:
    print("Error:", e)

# %%
class LowBalanceError(Exception):
    pass

class HighWithdrawalError(Exception):
    pass

def withdraw(balance, amount):
    if amount > balance:
        raise LowBalanceError("Insufficient balance")
    if amount > 10000:
        raise HighWithdrawalError("Limit exceeded")
    return balance - amount

# %%
try:
   withdraw(50000,15000)
except LowBalanceError as e1:
    print("Error:", e1)
except HighWithdrawalError as e2:
    print("Error:", e2)
else:
  print("Transaction Complete")
finally:
  print("Connection Terminated")

# %% [markdown]
# **Working with Moduled/Libraries**
#
# 1. Standard Libraries(built-in)- No installation needed
#
# 2. Third Party/External Libraries: numpy, pandas, install and import
#
# 3. Custom libraries: Define libraries and functions

# %%
import math
print(math.factorial(5))

# %%
#Alias
import pandas as pd
import math as mt
print(mt.sqrt(64))

# %%
from math import ceil,floor
print(ceil(45.3698))

# %%
#Custom Libraries
import mymodule as mm
print(mm.even_items([78,63,95,62,38,78,45,23,65,23,12,52,63]))
print(mm.Data_Validation(123,'abc'))

# %%
#Suggested Libraries: str, datetime, sys, os, random, math
